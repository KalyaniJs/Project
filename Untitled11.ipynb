# %%
#Project1:Analyzing Indian Premier League (IPL) Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'season': [2023, 2023, 2023, 2022, 2022, 2022, 2021, 2021, 2021],
    'team1': ['MI', 'CSK', 'RCB', 'MI', 'KKR', 'CSK', 'DC', 'RCB', 'MI'],
    'team2': ['CSK', 'RCB', 'MI', 'KKR', 'CSK', 'MI', 'MI', 'CSK', 'KKR'],
    'winner': ['MI', 'CSK', 'MI', 'MI', 'KKR', 'CSK', 'DC', 'RCB', 'MI'],
    'city': ['Mumbai', 'Chennai', 'Bangalore', 'Kolkata', 'Chennai', 'Mumbai', 'Delhi', 'Bangalore', 'Kolkata'],
    'player_of_match': ['Rohit Sharma', 'MS Dhoni', 'Virat Kohli', 'Jasprit Bumrah', 'Andre Russell',
                        'Ravindra Jadeja', 'Shikhar Dhawan', 'Rishabh Pant', 'AB de Villiers'],
    'runs_scored': [160, 180, 175, 150, 200, 190, 170, 185, 165],
}

# Create DataFrame
ipl_df = pd.DataFrame(data)

# %%
#1. Basic Data Exploration
print(ipl_df.head()) # View the first few rows
print(ipl_df.info()) # Get information about columns and data types
# Out:
#    season team1 team2 winner       city player_of_match  runs_scored
# 0    2023    MI   CSK     MI     Mumbai    Rohit Sharma          160
# 1    2023   CSK   RCB    CSK    Chennai        MS Dhoni          180
# 2    2023   RCB    MI     MI  Bangalore     Virat Kohli          175
# 3    2022    MI   KKR     MI    Kolkata  Jasprit Bumrah          150
# 4    2022   KKR   CSK    KKR    Chennai   Andre Russell          200
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           9 non-null      int64
#  1   team1            9 non-null      object
#  2   team2            9 non-null      object
#  3   winner           9 non-null      object
#  4   city             9 non-null      object
#  5   player_of_match  9 non-null      object
#  6   runs_scored      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 636.0+ bytes
# None

# %%
#2.Team Performance
team_wins =ipl_df['winner'].value_counts()
print("\nTeam Wins:\n", team_wins)
# Out:
# Team Wins:
#  winner
# MI     4
# CSK    2
# KKR    1
# DC     1
# RCB    1
# Name: count, dtype: int64

# %%
#3.Player of the Match Analysis
publish_display_data = ipl_df['player_of_match'].value_counts()
print("\nPlayer of the Match Analysis:\n", publish_display_data)
# Out:
# Player of the Match Analysis:
#  player_of_match
# Rohit Sharma       1
# MS Dhoni           1
# Virat Kohli        1
# Jasprit Bumrah     1
# Andre Russell      1
# Ravindra Jadeja    1
# Shikhar Dhawan     1
# Rishabh Pant       1
# AB de Villiers     1
# Name: count, dtype: int64

# %%
#4.Runs Scored Analysis
average_runs_per_match = ipl_df['runs_scored'].mean()
print("\nAverage Runs Scored per Match:", average_runs_per_match)
# Out:
# Average Runs Scored per Match: 175.0

# %%
#1.Bar Chart of Team Wins
plt.figure(figsize=(10, 6))
sns.countplot(x='winner',data=ipl_df)
plt.title('Number of Wins by Team')
plt.xlabel('Team')
plt.ylabel('Number of Wins')
plt.show()

# %%
#2.Histogram of Runs scored
plt.figure(figsize=(8, 5))
plt.hist(ipl_df['runs_scored'],bins=8)
plt.title('Distribution of Runs Scored')
plt.xlabel('Runs Scored')
plt.ylabel('Frequency')
plt.show()

# %%
#Project2:Explorating Trends in Indian Demographics

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#sample Indian Demographics(Replace with real data from census of India)
data = {
    'state': ['Maharashtra', 'Uttar Pradesh', 'Bihar', 'West Bengal', 'Tamil Nadu',
              'Madhya Pradesh', 'Rajasthan', 'Karnataka', 'Gujarat', 'Andhra Pradesh'],
    'population': [123144223, 237882725, 124799926, 99609303, 77841267,
                   85034723, 81032689, 67357546, 53903393, 49386799],
    'literacy_rate': [82.9, 73.0, 63.8, 77.1, 80.3, 70.6, 67.1, 75.6, 79.3, 67.4],
    'rural_population_percent': [54.8, 77.7, 88.7, 68.1, 51.7, 72.4, 75.1, 61.3, 57.4, 66.6],
}

# Create DataFrame
demographics_df = pd.DataFrame(data)

# %%
#1.Basic Data Exploration
print(demographics_df.head()) # View the first few rows
print(demographics_df.info()) # Get information about columns and data types
# Out:
#            state  population  literacy_rate  rural_population_percent
# 0    Maharashtra   123144223           82.9                      54.8
# 1  Uttar Pradesh   237882725           73.0                      77.7
# 2          Bihar   124799926           63.8                      88.7
# 3    West Bengal    99609303           77.1                      68.1
# 4     Tamil Nadu    77841267           80.3                      51.7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   state                     10 non-null     object
#  1   population                10 non-null     int64
#  2   literacy_rate             10 non-null     float64
#  3   rural_population_percent  10 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 452.0+ bytes
# None

# %%
#2.Population Analysis
total_population = demographics_df['population'].sum()
print("\nTotal Population of the Listed States", total_population)
# Out:
# Total Population of the Listed States 999992594

# %%
#3.Literacy Rate Analysis
average_literacy_rate = demographics_df['literacy_rate'].mean()
print("\nAverage Literacy Rate", average_literacy_rate)
# Out:
# Average Literacy Rate 73.70999999999998

# %%
#4.correlation between literacy rate and rural population
correlation = demographics_df['literacy_rate'].corr(demographics_df['rural_population_percent'])
print("\nCorrelation between Literacy Rate and Rural Population:", correlation)
# Out:
# Correlation between Literacy Rate and Rural Population: -0.8555070354105425

# %%
#1.Bar chart of population by state
plt.figure(figsize=(12, 6))
sns.barplot(x='state', y='population', data=demographics_df)
plt.title('Population by States')
plt.xlabel('State')
plt.ylabel('Population')
plt.xticks(rotation=45)
plt.show()

# %%
#2.Scatter plot of Literacy Rate vs. Rural Population
plt.figure(figsize=(8,6))
sns.scatterplot(x='literacy_rate', y='rural_population_percent', data=demographics_df)
plt.title('Literacy Rate vs. Rural Population Percentage')
plt.xlabel('Literacy Rate (%)')
plt.ylabel('Rural Population (%)')
plt.show()

# %%
#Project3:Examining Air Quality in Indian Cities

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#sample air quality data for indian cities(Replace With real data from CPCB)
data={
    'city':['Mumbai','Delhi','Bangalore','Kolkata','Chennai','Hyderabad','Ahmedabad','Pune','Jaipur','Lucknow'],
    'date':pd.to_datetime(['2023-01-15','2023-01-15','2023-01-15','2023-01-15','2023-01-15','2023-01-15','2023-01-15','2023-01-15','2023-01-15','2023-01-15']),
    'pm25':[250,120,180,90,70,150,110,160,200,140],
    'no2':[80,50,60,40,30,70,45,65,90,55],
    'so2':[30,20,25,15,10,25,18,28,35,22],
}
air_quality_df=pd.DataFrame(data) # This line defines the DataFrame

# %%
#1.Basic Data Exploration
print(air_quality_df.head())
print(air_quality_df.info())
# Out:
#         city       date  pm25  no2  so2
# 0     Mumbai 2023-01-15   250   80   30
# 1      Delhi 2023-01-15   120   50   20
# 2  Bangalore 2023-01-15   180   60   25
# 3    Kolkata 2023-01-15    90   40   15
# 4    Chennai 2023-01-15    70   30   10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    10 non-null     object
#  1   date    10 non-null     datetime64[ns]
#  2   pm25    10 non-null     int64
#  3   no2     10 non-null     int64
#  4   so2     10 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 532.0+ bytes
# None

# %%
#2.PM2.5 Analysis
average_pm25 = air_quality_df['pm25'].mean()
print("\nAverage PM2.5 cities:", average_pm25)
# Out:
# Average PM2.5 cities: 147.0

# %%
#3.city with highest NO2 Levels
city_highest_no2 = air_quality_df.loc[air_quality_df['no2'].idxmax(), 'city']
print("\nCity with the Highest NO2 Levels:", city_highest_no2)
# Out:
# City with the Highest NO2 Levels: Jaipur

# %%
#4:Correalation between pollutants
correlation_pm25_no2 = air_quality_df['pm25'].corr(air_quality_df['no2'])
print("\nCorrelation between PM2.5 and NO2:", correlation_pm25_no2)
# Out:
# Correlation between PM2.5 and NO2: 0.9039981305184133

# %%
#1.Bar Chart of PM2.5 Levels by city
plt.figure(figsize=(12, 6))
sns.barplot(x='city', y='pm25', data=air_quality_df)
plt.title('PM2.5 Levels by City')
plt.xlabel('City')
plt.ylabel('PM2.5 Level')
plt.xticks(rotation=45)
plt.show()

# %%
#2.scatter plot of PM2.5 vs NO2
plt.figure(figsize=(8, 6))
sns.scatterplot(x='pm25', y='no2', data=air_quality_df, hue='city')
plt.title('PM2.5 vs NO2 Levels')
plt.xlabel('PM2.5 Level')
plt.ylabel('NO2 Level')
plt.show()

# %%
#Project4:Understanding Movie Trends in Bollywood

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#sample Bollywood Movie Data (Replace with Real data from IMDb or other sources)
data = {
    'movie_title':['Movie A', 'Movie B', 'Movie C', 'Movie D', 'Movie E', 'Movie F', 'Movie G', 'Movie H', 'Movie I', 'Movie J'],
    'genre':['Action','Romance','Comedy','Drama','Action','Comedy','Romance','Thriller','Drama','Action'],
    'release_year':[2023,2022,2023,2021,2022,2023,2020,2022,2021,2023],
    'box_office_crores':[150,80,120,60,200,100,90,70,50,180],
    'lead_actor':['Actor X','Actor Y','Actor Z','Actor X','Actor Y','Actor Z','Actor X','Actor Y','Actor Z','Actor X'],
}

bollywood_df = pd.DataFrame(data)

# %%
#1. Basic Data Exploration
print(bollywood_df.head())
print(bollywood_df.info())
# Out:
#   movie_title    genre  release_year  box_office_crores lead_actor
# 0     Movie A   Action          2023                150    Actor X
# 1     Movie B  Romance          2022                 80    Actor Y
# 2     Movie C   Comedy          2023                120    Actor Z
# 3     Movie D    Drama          2021                 60    Actor X
# 4     Movie E   Action          2022                200    Actor Y
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_title        10 non-null     object
#  1   genre              10 non-null     object
#  2   release_year       10 non-null     int64
#  3   box_office_crores  10 non-null     int64
#  4   lead_actor         10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes
# None

# %%
#2. Genre Analysis
genre_counts = bollywood_df['genre'].value_counts()
print("\nMovie Count by Genre:\n", genre_counts)
# Out:
# Movie Count by Genre:
#  genre
# Action      3
# Romance     2
# Comedy      2
# Drama       2
# Thriller    1
# Name: count, dtype: int64

# %%
#3. Box office collection by Genre
box_office_by_genre = bollywood_df.groupby('genre')['box_office_crores'].sum()
print("\nTotal Box Office Collection by Genre:\n", box_office_by_genre)
# Out:
# Total Box Office Collection by Genre:
#  genre
# Action      530
# Comedy      220
# Drama       110
# Romance     170
# Thriller     70
# Name: box_office_crores, dtype: int64

# %%
#4.Lead Actor Analysis
lead_actor_box_office = bollywood_df.groupby('lead_actor')['box_office_crores'].sum()
print("\nTotal Box Office Collection by Lead Actor:\n", lead_actor_box_office)
# Out:
# Total Box Office Collection by Lead Actor:
#  lead_actor
# Actor X    480
# Actor Y    350
# Actor Z    270
# Name: box_office_crores, dtype: int64

# %%
#1.Bar Chart of MOvie Count by Genre
plt.figure(figsize=(10, 6))
sns.countplot(x='genre', data=bollywood_df)
plt.title('Number of Movie by Genre')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.show()

# %%
#2.Pie Chart of Box Office Collection by Genre
plt.figure(figsize=(8, 8))
plt.pie(box_office_by_genre, labels=box_office_by_genre.index, autopct='%1.1f%%', startangle=140)
plt.title('Box Office Collection by Genre')
plt.show()
